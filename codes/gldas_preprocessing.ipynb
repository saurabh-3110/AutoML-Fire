# %%
from netCDF4 import Dataset

# Specify the path to your NetCDF file
nc_file = '/Volumes/One Touch/Wildfire/data_in_nc4/soil_moisture/2003/GLDAS_CLSM025_DA1_D.A20030201.022.nc4.SUB.nc4'
# Open the NetCDF file
with Dataset(nc_file, 'r') as nc:
    # Get variable names and print them
    variable_names = nc.variables.keys()
    for var_name in variable_names:
        print(var_name)
# Out:
# time
# time_bnds
# lon
# lat
# SoilMoist_RZ_tavg
# ACond_tavg

# %%
import os
import xarray as xr
import pandas as pd
import numpy as np
# Define the path to the main folder containing all the year folders
main_folder_path = "data_in_nc4/soil_moisture"  # In this folder make sure you have folders like 2000, 2001, etc.

# Define the path to the output folder where all yearly output folders will be saved
output_main_folder_path = "raw/files/soil_moisture"

# Create the output folder if it does not exist
os.makedirs(output_main_folder_path, exist_ok=True)

# Iterate over year folders in the main folder
for year_folder_name in os.listdir(main_folder_path):
    # Construct the full path to the year folder
    year_folder_path = os.path.join(main_folder_path, year_folder_name)
    
    # Check if the item in the main folder is indeed a directory
    if os.path.isdir(year_folder_path):
        # Define the path to the new folder where CSV files will be saved for this year
        output_year_folder_path = os.path.join(output_main_folder_path, f"{year_folder_name}_unique_coordinates")
        os.makedirs(output_year_folder_path, exist_ok=True)
        
        # Iterate over files in the year folder
        for file_name in os.listdir(year_folder_path):
            # Check if the file is a NetCDF file
            if file_name.endswith(".nc4.SUB.nc4"):
                # Construct the full path to the file
                file_path = os.path.join(year_folder_path, file_name)
                
                # Perform the operations as in the previous code snippet
                original_data = xr.open_dataset(file_path)
                file_date = file_name.split('.')[1][1:]
                lat_name = [dim for dim in original_data.coords if 'lat' in dim][0]
                lon_name = [dim for dim in original_data.coords if 'lon' in dim][0]
                target_lat = np.arange(6.5, 38.5, 0.25)
                target_lon = np.arange(66.5, 100, 0.25)
                regridded_data = original_data.interp({lat_name: target_lat, lon_name: target_lon}, method='nearest')
                regridded_data = regridded_data[['SoilMoist_RZ_tavg']]
                regridded_dataframe = regridded_data.to_dataframe().reset_index()
                unique_coordinates = regridded_dataframe.drop_duplicates(subset=['lat', 'lon'])
                csv_file_path = os.path.join(output_year_folder_path, f"{file_date}.csv")
                unique_coordinates.to_csv(csv_file_path, index=False)
                
                print(f"Processed {file_path} and saved output to {csv_file_path}")
# Out:
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090101.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090101.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090102.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090102.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090103.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090103.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090104.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090104.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090105.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090105.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090106.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090106.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090107.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090107.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090108.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090108.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090110.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090110.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090111.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090111.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090112.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090112.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090113.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090113.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090114.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090114.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090115.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090115.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090116.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090116.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090117.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090117.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090118.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090118.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090119.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090119.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090120.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090120.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090121.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090121.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090122.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090122.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090123.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090123.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090124.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090124.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090125.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090125.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090126.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090126.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090127.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090127.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090128.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090128.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090129.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090129.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090130.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090130.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090131.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090131.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090201.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090201.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090202.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090202.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090203.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090203.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090204.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090204.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090205.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090205.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090206.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090206.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090207.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090207.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090208.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090208.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090209.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090209.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090210.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090210.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090211.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090211.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090212.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090212.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090213.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090213.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090214.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090214.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090215.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090215.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090216.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090216.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090217.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090217.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090218.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090218.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090219.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090219.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090220.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090220.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090221.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20
csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090905.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090905.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090906.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090906.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090907.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090907.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090908.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090908.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090909.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090909.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090910.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090910.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090911.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090911.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090912.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090912.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090913.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090913.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090914.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090914.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090915.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090915.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090916.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090916.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090917.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090917.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090918.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090918.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090919.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090919.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090920.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090920.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090921.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090921.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090922.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090922.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090923.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090923.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090924.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090924.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090925.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090925.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090926.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090926.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090927.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090927.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090928.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090928.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090929.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090929.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20090930.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20090930.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091001.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091001.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091002.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091002.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091003.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091003.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091004.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091004.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091005.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091005.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091006.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091006.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091007.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091007.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091008.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091008.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091009.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091009.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091010.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091010.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091011.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091011.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091012.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091012.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091013.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091013.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091014.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091014.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091015.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091015.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091016.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091016.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091017.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091017.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091018.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091018.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091019.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091019.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091020.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091020.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091021.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091021.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091022.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091022.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091023.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091023.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091024.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091024.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091025.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091025.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091026.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091026.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091027.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091027.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091028.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091028.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091029.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091029.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091030.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091030.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091031.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091031.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091101.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091101.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091102.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091102.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091103.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091103.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091104.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091104.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091105.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091105.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091106.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091106.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091107.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091107.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091108.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091108.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091109.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091109.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091110.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091110.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091111.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091111.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091112.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091112.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091113.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091113.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091114.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091114.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091115.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091115.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091116.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091116.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091117.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091117.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091118.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091118.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091119.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091119.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091120.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091120.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091121.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091121.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091122.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091122.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091123.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091123.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091124.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091124.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091125.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091125.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091126.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091126.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091127.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091127.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091128.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091128.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091129.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091129.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091130.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091130.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091201.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091201.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091202.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091202.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091203.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091203.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091204.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091204.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091205.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091205.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091206.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091206.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091207.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091207.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091208.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091208.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091209.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091209.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091210.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091210.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091211.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091211.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091212.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091212.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091213.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091213.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091214.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091214.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091215.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091215.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091216.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091216.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091217.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091217.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091218.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091218.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091219.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091219.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091220.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091220.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091221.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091221.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091222.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091222.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091223.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091223.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091224.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091224.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091225.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091225.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091226.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091226.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091227.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091227.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091228.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091228.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091229.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091229.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091230.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091230.csv
# Processed 2009_dddd\2009_new\GLDAS_CLSM025_DA1_D.A20091231.022.nc4.SUB.nc4 and saved output to soil_moisture_csv\2009_new_unique_coordinates\20091231.csv

# %%
import os
import pandas as pd

# Define the path to the yearly output folder
yearly_output_folder = "raw/files/soil_moisture"  # This should match the output folder created above

# Iterate over year folders in the yearly output folder
for year_folder_name in os.listdir(yearly_output_folder):
    # Construct the full path to the year folder
    year_folder_path = os.path.join(yearly_output_folder, year_folder_name)
    
    # Check if the item in the yearly output folder is indeed a directory
    if os.path.isdir(year_folder_path):
        # Collect all CSV files in the year folder
        csv_files = [file for file in os.listdir(year_folder_path) if file.endswith('.csv')]
        
        # Initialize an empty DataFrame to hold the combined data
        combined_data = pd.DataFrame(columns=['lat', 'lon'])
        
        # Iterate over each CSV file in the year folder
        for csv_file_name in csv_files:
            # Read the CSV file into a DataFrame
            csv_file_path = os.path.join(year_folder_path, csv_file_name)
            df = pd.read_csv(csv_file_path)
            
            # Extract the date from the CSV file name
            date = csv_file_name.split('.')[0]
            
            # Rename the 'SoilMoist_RZ_tavg' column to the date
            df.rename(columns={'SoilMoist_RZ_tavg': date}, inplace=True)
            
            # Merge the current DataFrame with the combined DataFrame based on lat and lon
            combined_data = pd.merge(combined_data, df[['lat', 'lon', date]], on=['lat', 'lon'], how='outer')
        
        # Reorder the columns to have lat and lon as the first two columns
        combined_data = combined_data[['lat', 'lon'] + [col for col in combined_data.columns if col not in ['lat', 'lon']]]
        
        # Save the combined DataFrame to a CSV file
        output_csv_path = os.path.join(yearly_output_folder, f"{year_folder_name}.csv")
        combined_data.to_csv(output_csv_path, index=False)
        
        print(f"Combined data for {year_folder_name} and saved to {output_csv_path}")
# Out:
# Combined data for 2009_new_unique_coordinates and saved to sm1\2009_new_unique_coordinates.csv

# %% [markdown]
# Save the yearly files seaprately to a folder (yearly_files/soilmoisture)

# %%
import pandas as pd
import os

def transpose_csv(input_folder, output_folder):
    # Walk through the directory tree
    for root, dirs, files in os.walk(input_folder):
        for filename in files:
            # Skip hidden macOS metadata files
            if filename.endswith('.csv') and not filename.startswith('._'):
                input_file = os.path.join(root, filename)
                try:
                    # Read the CSV file into a pandas DataFrame
                    df = pd.read_csv(input_file)
                    
                    # Transpose the DataFrame
                    df_transposed = df.T
                    
                    # Construct the output folder path mirroring the input folder structure
                    relative_path = os.path.relpath(root, input_folder)
                    output_subfolder = os.path.join(output_folder, relative_path)
                    
                    # Create the output subfolder if it doesn't exist
                    os.makedirs(output_subfolder, exist_ok=True)
                    
                    # Generate the output filename
                    output_file = os.path.join(output_subfolder, filename)
                    
                    # Write the transposed DataFrame to a new CSV file
                    df_transposed.to_csv(output_file, index=True, header=False)
                    print(f"Transposed and saved: {input_file} -> {output_file}")
                except Exception as e:
                    print(f"Error processing file {input_file}: {e}")

if __name__ == "__main__":
    input_folder = "yearly_files/soilmositure"
    output_folder = "transposed/soilmoisture"

    os.makedirs(output_folder, exist_ok=True)

    transpose_csv(input_folder, output_folder)
    print("Transposition complete.")

# %%
import csv
import os
import pandas as pd

def transform_files(input_folder, output_file):
    # Initialize an empty DataFrame to store transformed data from all files
    combined_df = pd.DataFrame()

    # Iterate through each file in the input folder
    for filename in os.listdir(input_folder):
        # Skip hidden metadata files
        if filename.endswith('.csv') and not filename.startswith('._'):
            input_file = os.path.join(input_folder, filename)
            try:
                # Read the file and transform the data
                transformed_df = transform_file(input_file)
                # Append transformed data to the combined DataFrame
                combined_df = pd.concat([combined_df, transformed_df], ignore_index=True)
            except Exception as e:
                print(f"Error processing file {input_file}: {e}")

    # Write the combined DataFrame to a single output file
    combined_df.to_csv(output_file, index=False)
    print("Transformation complete. Combined data saved to:", output_file)

def transform_file(input_file):
    transformed_rows = []

    with open(input_file, 'r') as f_in:
        reader = csv.reader(f_in)
        latitudes = next(reader)
        longitudes = next(reader)
        # Skip the header row
        next(reader)
        for row in reader:
            date = row[0]
            values = row[1:]
            for lat, lon, value in zip(latitudes, longitudes, values):
                transformed_rows.append([lat, lon, date, value])

    # Convert transformed rows to a DataFrame
    transformed_df = pd.DataFrame(transformed_rows, columns=['Lat', 'Lon', 'Date', 'soilmoisture'])  # Adjust column names as needed
    return transformed_df

if __name__ == "__main__":
    input_folder = 'transposed/soilmoisture'  # Specify the input folder containing CSV files
    output_file = 'variables/soilmoisture.csv'  # Specify the output file name
    
    transform_files(input_folder, output_file)
