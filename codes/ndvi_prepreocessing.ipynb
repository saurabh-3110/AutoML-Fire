# %%
import os
import re
import xarray as xr
import pandas as pd
import numpy as np
from datetime import datetime
import logging

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Define the target latitude and longitude grids with 0.25 spacing
target_lat = np.arange(6.5, 38.5, 0.25)  # Target latitude grid with 0.25 spacing
target_lon = np.arange(66.5, 100, 0.25)  # Target longitude grid with 0.25 spacing

# Define the base path for the input and output directories
base_input_path = "data_in_nc4/NDVI"
base_output_path = "raw_files/ndvi"

# Ensure the base output directory exists
os.makedirs(base_output_path, exist_ok=True)

# Function to process a single NetCDF file
def process_file(file_path, target_lat, target_lon, output_file_path):
    try:
        logging.info(f"Processing file: {file_path}")
        
        original_data = xr.open_dataset(file_path, decode_times=False)
        lat_name = [dim for dim in original_data.coords if 'lat' in dim][0]
        lon_name = [dim for dim in original_data.coords if 'lon' in dim][0]
        
        regridded_data = original_data.interp({lat_name: target_lat, lon_name: target_lon}, method='nearest')
        regridded_data = regridded_data[['NDVI']]
        
        regridded_dataframe = regridded_data.to_dataframe().reset_index()
        regridded_dataframe = regridded_dataframe.rename(columns={lat_name: 'lat', lon_name: 'lon'})
        
        unique_coordinates = regridded_dataframe.drop_duplicates(subset=['lat', 'lon'])
        
        os.makedirs(os.path.dirname(output_file_path), exist_ok=True)
        unique_coordinates.to_csv(output_file_path, index=False)
        logging.info(f"Processed and saved: {output_file_path}")
    except Exception as e:
        logging.error(f"Failed to process file {file_path} due to {e}")

# Walk through the directory structure and process each file
for root, dirs, files in os.walk(base_input_path):
    for file in files:
        if file.endswith(".nc"):
            input_file_path = os.path.join(root, file)
            
            # Extracting the date from the file name using regex
            match = re.search(r'\d{8}', file)  # Assuming the date format is YYYYMMDD
            if match:
                file_date = datetime.strptime(match.group(), '%Y%m%d').strftime('%Y-%m-%d')
            else:
                logging.warning(f"Date not found in filename: {file}")
                continue
            
            # Construct the output file path with date included in the file name
            relative_path = os.path.relpath(root, base_input_path)
            output_file_path = os.path.join(base_output_path, relative_path, f"NDVI_{file_date}.csv")
            
            # Process the file and save the output
            process_file(input_file_path, target_lat, target_lon, output_file_path)

logging.info("Processing completed.")
# Out:
# 2024-06-06 11:24:05,322 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160101_c20240124214015.nc
# 2024-06-06 11:24:06,983 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-01.csv
# 2024-06-06 11:24:06,993 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160102_c20240124214208.nc
# 2024-06-06 11:24:07,662 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-02.csv
# 2024-06-06 11:24:07,677 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160103_c20240124214416.nc
# 2024-06-06 11:24:08,442 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-03.csv
# 2024-06-06 11:24:08,460 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160104_c20240124214622.nc
# 2024-06-06 11:24:09,142 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-04.csv
# 2024-06-06 11:24:09,161 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160105_c20240124214804.nc
# 2024-06-06 11:24:09,861 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-05.csv
# 2024-06-06 11:24:09,868 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160106_c20240124214954.nc
# 2024-06-06 11:24:10,602 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-06.csv
# 2024-06-06 11:24:10,608 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160107_c20240124215124.nc
# 2024-06-06 11:24:11,298 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-07.csv
# 2024-06-06 11:24:11,304 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160108_c20240124215309.nc
# 2024-06-06 11:24:12,012 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-08.csv
# 2024-06-06 11:24:12,018 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160109_c20240124215504.nc
# 2024-06-06 11:24:12,735 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-09.csv
# 2024-06-06 11:24:12,740 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160110_c20240124215644.nc
# 2024-06-06 11:24:13,446 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-10.csv
# 2024-06-06 11:24:13,451 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160111_c20240124215826.nc
# 2024-06-06 11:24:14,291 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-11.csv
# 2024-06-06 11:24:14,300 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160112_c20240124220045.nc
# 2024-06-06 11:24:15,016 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-12.csv
# 2024-06-06 11:24:15,033 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160113_c20240124220235.nc
# 2024-06-06 11:24:15,744 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-13.csv
# 2024-06-06 11:24:15,750 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160114_c20240124220416.nc
# 2024-06-06 11:24:16,457 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-14.csv
# 2024-06-06 11:24:16,462 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160115_c20240124220614.nc
# 2024-06-06 11:24:17,236 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-15.csv
# 2024-06-06 11:24:17,243 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160116_c20240124220837.nc
# 2024-06-06 11:24:17,983 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-16.csv
# 2024-06-06 11:24:17,994 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160117_c20240124221015.nc
# 2024-06-06 11:24:18,705 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-17.csv
# 2024-06-06 11:24:18,705 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160118_c20240124221218.nc
# 2024-06-06 11:24:19,435 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-18.csv
# 2024-06-06 11:24:19,453 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160119_c20240124221409.nc
# 2024-06-06 11:24:20,202 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-19.csv
# 2024-06-06 11:24:20,211 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160120_c20240124221613.nc
# 2024-06-06 11:24:20,880 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-20.csv
# 2024-06-06 11:24:20,889 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160121_c20240124221754.nc
# 2024-06-06 11:24:21,627 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-21.csv
# 2024-06-06 11:24:21,631 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160122_c20240124221957.nc
# 2024-06-06 11:24:22,332 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-22.csv
# 2024-06-06 11:24:22,348 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160123_c20240124222142.nc
# 2024-06-06 11:24:23,081 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-23.csv
# 2024-06-06 11:24:23,093 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160124_c20240124222353.nc
# 2024-06-06 11:24:23,831 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-24.csv
# 2024-06-06 11:24:23,838 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160125_c20240124222619.nc
# 2024-06-06 11:24:24,571 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-25.csv
# 2024-06-06 11:24:24,578 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160126_c20240124222759.nc
# 2024-06-06 11:24:25,229 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-26.csv
# 2024-06-06 11:24:25,235 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160127_c20240124223024.nc
# 2024-06-06 11:24:25,957 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-27.csv
# 2024-06-06 11:24:25,971 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160128_c20240124223205.nc
# 2024-06-06 11:24:26,689 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-28.csv
# 2024-06-06 11:24:26,709 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160129_c20240124223351.nc
# 2024-06-06 11:24:27,443 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-29.csv
# 2024-06-06 11:24:27,448 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160130_c20240124223548.nc
# 2024-06-06 11:24:28,144 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-30.csv
# 2024-06-06 11:24:28,163 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160131_c20240124223736.nc
# 2024-06-06 11:24:28,846 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-01-31.csv
# 2024-06-06 11:24:28,867 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160201_c20240124223933.nc
# 2024-06-06 11:24:29,615 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-01.csv
# 2024-06-06 11:24:29,615 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160202_c20240124224140.nc
# 2024-06-06 11:24:30,356 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-02.csv
# 2024-06-06 11:24:30,376 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160203_c20240124224319.nc
# 2024-06-06 11:24:31,089 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-03.csv
# 2024-06-06 11:24:31,103 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160204_c20240124224526.nc
# 2024-06-06 11:24:31,833 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-04.csv
# 2024-06-06 11:24:31,838 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160205_c20240124224710.nc
# 2024-06-06 11:24:32,536 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-05.csv
# 2024-06-06 11:24:32,543 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160206_c20240124224856.nc
# 2024-06-06 11:24:33,315 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-06.csv
# 2024-06-06 11:24:33,322 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160207_c20240124225056.nc
# 2024-06-06 11:24:34,088 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-07.csv
# 2024-06-06 11:24:34,094 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160208_c20240124225354.nc
# 2024-06-06 11:24:34,836 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-08.csv
# 2024-06-06 11:24:34,842 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160209_c20240124225539.nc
# 2024-06-06 11:24:35,596 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-09.csv
# 2024-06-06 11:24:35,606 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160210_c20240124225731.nc
# 2024-06-06 11:24:36,349 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-10.csv
# 2024-06-06 11:24:36,368 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160211_c20240124230018.nc
# 2024-06-06 11:24:37,108 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-11.csv
# 2024-06-06 11:24:37,127 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160212_c20240124230206.nc
# 2024-06-06 11:24:37,893 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-12.csv
# 2024-06-06 11:24:37,912 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160213_c20240124230350.nc
# 2024-06-06 11:24:38,697 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-13.csv
# 2024-06-06 11:24:38,713 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160214_c20240124230545.nc
# 2024-06-06 11:24:39,474 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-14.csv
# 2024-06-06 11:24:39,479 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160215_c20240124230747.nc
# 2024-06-06 11:24:40,254 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-15.csv
# 2024-06-06 11:24:40,259 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160216_c20240124230938.nc
# 2024-06-06 11:24:40,973 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-16.csv
# 2024-06-06 11:24:40,978 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160217_c20240124231125.nc
# 2024-06-06 11:24:41,713 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-17.csv
# 2024-06-06 11:24:41,727 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160218_c20240124231345.nc
# 2024-06-06 11:24:42,476 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-18.csv
# 2024-06-06 11:24:42,480 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160219_c20240124231535.nc
# 2024-06-06 11:24:43,154 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-19.csv
# 2024-06-06 11:24:43,173 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160220_c20240124231718.nc
# 2024-06-06 11:24:44,022 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-20.csv
# 2024-06-06 11:24:44,034 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160221_c20240124231901.nc
# 2024-06-06 11:24:44,949 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-21.csv
# 2024-06-06 11:24:44,963 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160222_c20240124232109.nc
# 2024-06-06 11:24:45,696 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-22.csv
# 2024-06-06 11:24:45,701 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160223_c20240124232300.nc
# 2024-06-06 11:24:46,364 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-23.csv
# 2024-06-06 11:24:46,369 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160224_c20240124232512.nc
# 2024-06-06 11:24:47,131 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-24.csv
# 2024-06-06 11:24:47,136 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160225_c20240124232700.nc
# 2024-06-06 11:24:47,842 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-25.csv
# 2024-06-06 11:24:47,854 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160226_c20240124232845.nc
# 2024-06-06 11:24:48,587 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-26.csv
# 2024-06-06 11:24:48,596 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160227_c20240124233028.nc
# 2024-06-06 11:24:49,361 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-27.csv
# 2024-06-06 11:24:49,381 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160228_c20240124233219.nc
# 2024-06-06 11:24:50,112 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-28.csv
# 2024-06-06 11:24:50,118 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160229_c20240124233405.nc
# 2024-06-06 11:24:50,849 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-02-29.csv
# 2024-06-06 11:24:50,853 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160301_c20240124233630.nc
# 2024-06-06 11:24:51,595 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-01.csv
# 2024-06-06 11:24:51,615 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160302_c20240124233835.nc
# 2024-06-06 11:24:52,356 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-02.csv
# 2024-06-06 11:24:52,372 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160303_c20240124234031.nc
# 2024-06-06 11:24:53,125 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-03.csv
# 2024-06-06 11:24:53,144 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160304_c20240124234226.nc
# 2024-06-06 11:24:53,858 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-04.csv
# 2024-06-06 11:24:53,877 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160305_c20240124234430.nc
# 2024-06-06 11:24:54,608 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-05.csv
# 2024-06-06 11:24:54,623 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160306_c20240124234627.nc
# 2024-06-06 11:24:55,323 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-06.csv
# 2024-06-06 11:24:55,339 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160307_c20240124234817.nc
# 2024-06-06 11:24:56,001 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-07.csv
# 2024-06-06 11:24:56,007 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160308_c20240124235001.nc
# 2024-06-06 11:24:56,725 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-08.csv
# 2024-06-06 11:24:56,730 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160309_c20240124235157.nc
# 2024-06-06 11:24:57,454 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-09.csv
# 2024-06-06 11:24:57,460 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160310_c20240124235446.nc
# 2024-06-06 11:24:58,166 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-10.csv
# 2024-06-06 11:24:58,176 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160311_c20240124235638.nc
# 2024-06-06 11:24:58,894 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-11.csv
# 2024-06-06 11:24:58,912 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160312_c20240124235827.nc
# 2024-06-06 11:24:59,688 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-12.csv
# 2024-06-06 11:24:59,700 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160313_c20240125000023.nc
# 2024-06-06 11:25:00,438 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-13.csv
# 2024-06-06 11:25:00,449 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160314_c20240125000226.nc
# 2024-06-06 11:25:01,220 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-14.csv
# 2024-06-06 11:25:01,239 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160315_c20240125000415.nc
# 2024-06-06 11:25:01,970 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-15.csv
# 2024-06-06 11:25:01,975 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160316_c20240125000644.nc
# 2024-06-06 11:25:02,695 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-16.csv
# 2024-06-06 11:25:02,699 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160317_c20240125000835.nc
# 2024-06-06 11:25:03,500 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-17.csv
# 2024-06-06 11:25:03,511 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160318_c20240125001018.nc
# 2024-06-06 11:25:04,335 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-18.csv
# 2024-06-06 11:25:04,351 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160319_c20240125001239.nc
# 2024-06-06 11:25:05,075 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-19.csv
# 2024-06-06 11:25:05,089 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160320_c20240125001453.nc
# 2024-06-06 11:25:05,808 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-20.csv
# 2024-06-06 11:25:05,825 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160321_c20240125001643.nc
# 2024-06-06 11:25:06,600 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-21.csv
# 2024-06-06 11:25:06,611 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160322_c20240125001846.nc
# 2024-06-06 11:25:07,259 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-22.csv
# 2024-06-06 11:25:07,272 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160323_c20240125002039.nc
# 2024-06-06 11:25:08,003 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-23.csv
# 2024-06-06 11:25:08,009 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160324_c20240125002408.nc
# 2024-06-06 11:25:08,735 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-24.csv
# 2024-06-06 11:25:08,740 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160325_c20240125002558.nc
# 2024-06-06 11:25:09,458 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-25.csv
# 2024-06-06 11:25:09,464 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160326_c20240125002801.nc
# 2024-06-06 11:25:10,223 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-26.csv
# 2024-06-06 11:25:10,230 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160327_c20240125002947.nc
# 2024-06-06 11:25:10,974 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-27.csv
# 2024-06-06 11:25:10,978 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160328_c20240125003132.nc
# 2024-06-06 11:25:11,738 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-28.csv
# 2024-06-06 11:25:11,744 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160329_c20240125003314.nc
# 2024-06-06 11:25:12,487 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-29.csv
# 2024-06-06 11:25:12,492 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160330_c20240125003505.nc
# 2024-06-06 11:25:13,243 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-30.csv
# 2024-06-06 11:25:13,248 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160331_c20240125003654.nc
# 2024-06-06 11:25:14,026 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-03-31.csv
# 2024-06-06 11:25:14,037 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160401_c20240125003906.nc
# 2024-06-06 11:25:14,907 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-01.csv
# 2024-06-06 11:25:14,920 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160402_c20240125004046.nc
# 2024-06-06 11:25:15,720 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-02.csv
# 2024-06-06 11:25:15,728 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160403_c20240125004303.nc
# 2024-06-06 11:25:16,392 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-03.csv
# 2024-06-06 11:25:16,413 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160404_c20240125004600.nc
# 2024-06-06 11:25:17,127 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-04.csv
# 2024-06-06 11:25:17,136 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160405_c20240125004829.nc
# 2024-06-06 11:25:17,807 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-05.csv
# 2024-06-06 11:25:17,813 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160406_c20240125005021.nc
# 2024-06-06 11:25:18,574 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-06.csv
# 2024-06-06 11:25:18,580 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160407_c20240125005251.nc
# 2024-06-06 11:25:19,323 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-07.csv
# 2024-06-06 11:25:19,329 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160408_c20240125005444.nc
# 2024-06-06 11:25:20,076 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-08.csv
# 2024-06-06 11:25:20,082 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160409_c20240125005705.nc
# 2024-06-06 11:25:20,751 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-09.csv
# 2024-06-06 11:25:20,765 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160410_c20240125005849.nc
# 2024-06-06 11:25:21,468 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-10.csv
# 2024-06-06 11:25:21,474 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160411_c20240125010203.nc
# 2024-06-06 11:25:22,214 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-11.csv
# 2024-06-06 11:25:22,218 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160412_c20240125010421.nc
# 2024-06-06 11:25:22,965 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-12.csv
# 2024-06-06 11:25:22,971 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160413_c20240125010730.nc
# 2024-06-06 11:25:23,719 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-13.csv
# 2024-06-06 11:25:23,729 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160414_c20240125010940.nc
# 2024-06-06 11:25:24,476 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-14.csv
# 2024-06-06 11:25:24,476 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160415_c20240125011114.nc
# 2024-06-06 11:25:25,223 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-15.csv
# 2024-06-06 11:25:25,241 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160416_c20240125011256.nc
# 2024-06-06 11:25:25,990 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-16.csv
# 2024-06-06 11:25:25,997 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160417_c20240125011505.nc
# 2024-06-06 11:25:26,744 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-17.csv
# 2024-06-06 11:25:26,750 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160418_c20240125011741.nc
# 2024-06-06 11:25:27,501 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-18.csv
# 2024-06-06 11:25:27,509 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160419_c20240125011925.nc
# 2024-06-06 11:25:28,180 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-19.csv
# 2024-06-06 11:25:28,185 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160420_c20240125012107.nc
# 2024-06-06 11:25:28,933 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-20.csv
# 2024-06-06 11:25:28,941 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160421_c20240125012316.nc
# 2024-06-06 11:25:29,675 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-21.csv
# 2024-06-06 11:25:29,681 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160422_c20240125012524.nc
# 2024-06-06 11:25:30,422 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-22.csv
# 2024-06-06 11:25:30,427 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160423_c20240125012704.nc
# 2024-06-06 11:25:31,126 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-23.csv
# 2024-06-06 11:25:31,132 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160424_c20240125012840.nc
# 2024-06-06 11:25:31,868 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-24.csv
# 2024-06-06 11:25:31,887 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160425_c20240125013023.nc
# 2024-06-06 11:25:32,632 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-25.csv
# 2024-06-06 11:25:32,641 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160426_c20240125013237.nc
# 2024-06-06 11:25:33,556 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-26.csv
# 2024-06-06 11:25:33,561 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160427_c20240125013450.nc
# 2024-06-06 11:25:34,237 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-27.csv
# 2024-06-06 11:25:34,243 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160428_c20240125013712.nc
# 2024-06-06 11:25:34,896 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-28.csv
# 2024-06-06 11:25:34,902 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160429_c20240125013905.nc
# 2024-06-06 11:25:35,593 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-29.csv
# 2024-06-06 11:25:35,599 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160430_c20240125014138.nc
# 2024-06-06 11:25:36,314 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-04-30.csv
# 2024-06-06 11:25:36,321 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160501_c20240125014318.nc
# 2024-06-06 11:25:37,050 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-01.csv
# 2024-06-06 11:25:37,057 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160502_c20240125014529.nc
# 2024-06-06 11:25:37,719 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-02.csv
# 2024-06-06 11:25:37,723 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160503_c20240125014805.nc
# 2024-06-06 11:25:38,492 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-03.csv
# 2024-06-06 11:25:38,499 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160504_c20240125014946.nc
# 2024-06-06 11:25:39,203 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-04.csv
# 2024-06-06 11:25:39,218 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160505_c20240125015133.nc
# 2024-06-06 11:25:39,988 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-05.csv
# 2024-06-06 11:25:39,994 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160506_c20240125015316.nc
# 2024-06-06 11:25:40,742 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-06.csv
# 2024-06-06 11:25:40,747 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160507_c20240125015538.nc
# 2024-06-06 11:25:41,446 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-07.csv
# 2024-06-06 11:25:41,451 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160508_c20240125015728.nc
# 2024-06-06 11:25:42,168 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-08.csv
# 2024-06-06 11:25:42,187 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160509_c20240125015904.nc
# 2024-06-06 11:25:42,924 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-09.csv
# 2024-06-06 11:25:42,938 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160510_c20240125020053.nc
# 2024-06-06 11:25:43,641 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-10.csv
# 2024-06-06 11:25:43,647 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160511_c20240125020229.nc
# 2024-06-06 11:25:44,310 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-11.csv
# 2024-06-06 11:25:44,317 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160512_c20240125020402.nc
# 2024-06-06 11:25:45,352 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-12.csv
# 2024-06-06 11:25:45,357 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160513_c20240125020645.nc
# 2024-06-06 11:25:46,081 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-13.csv
# 2024-06-06 11:25:46,086 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160514_c20240125020903.nc
# 2024-06-06 11:25:46,765 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-14.csv
# 2024-06-06 11:25:46,777 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160515_c20240125021112.nc
# 2024-06-06 11:25:47,443 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-15.csv
# 2024-06-06 11:25:47,455 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160516_c20240125021345.nc
# 2024-06-06 11:25:48,178 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-16.csv
# 2024-06-06 11:25:48,185 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160517_c20240125021521.nc
# 2024-06-06 11:25:48,922 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-17.csv
# 2024-06-06 11:25:48,929 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160518_c20240125021718.nc
# 2024-06-06 11:25:49,679 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-18.csv
# 2024-06-06 11:25:49,684 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160519_c20240125022030.nc
# 2024-06-06 11:25:50,397 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-19.csv
# 2024-06-06 11:25:50,403 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160520_c20240125022321.nc
# 2024-06-06 11:25:51,163 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-20.csv
# 2024-06-06 11:25:51,168 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160521_c20240125022535.nc
# 2024-06-06 11:25:51,922 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-21.csv
# 2024-06-06 11:25:51,934 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160522_c20240125022823.nc
# 2024-06-06 11:25:52,588 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-22.csv
# 2024-06-06 11:25:52,599 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160523_c20240125022959.nc
# 2024-06-06 11:25:53,315 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-23.csv
# 2024-06-06 11:25:53,325 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160524_c20240125023315.nc
# 2024-06-06 11:25:54,072 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-24.csv
# 2024-06-06 11:25:54,079 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160525_c20240125023628.nc
# 2024-06-06 11:25:54,809 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-25.csv
# 2024-06-06 11:25:54,814 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160526_c20240125023838.nc
# 2024-06-06 11:25:55,584 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-26.csv
# 2024-06-06 11:25:55,590 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160527_c20240125024040.nc
# 2024-06-06 11:25:56,325 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-27.csv
# 2024-06-06 11:25:56,331 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160528_c20240125024222.nc
# 2024-06-06 11:25:57,044 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-28.csv
# 2024-06-06 11:25:57,050 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160529_c20240125024440.nc
# 2024-06-06 11:25:57,784 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-29.csv
# 2024-06-06 11:25:57,791 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160530_c20240125024659.nc
# 2024-06-06 11:25:58,518 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-30.csv
# 2024-06-06 11:25:58,525 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160531_c20240125024850.nc
# 2024-06-06 11:25:59,252 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-05-31.csv
# 2024-06-06 11:25:59,257 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160601_c20240125025034.nc
# 2024-06-06 11:26:00,035 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-01.csv
# 2024-06-06 11:26:00,046 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160602_c20240125025253.nc
# 2024-06-06 11:26:00,776 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-02.csv
# 2024-06-06 11:26:00,784 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160603_c20240125025511.nc
# 2024-06-06 11:26:01,528 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-03.csv
# 2024-06-06 11:26:01,533 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160604_c20240125025812.nc
# 2024-06-06 11:26:02,228 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-04.csv
# 2024-06-06 11:26:02,232 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160605_c20240125030049.nc
# 2024-06-06 11:26:02,945 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-05.csv
# 2024-06-06 11:26:02,950 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160606_c20240125030406.nc
# 2024-06-06 11:26:03,595 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-06.csv
# 2024-06-06 11:26:03,603 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160607_c20240125030634.nc
# 2024-06-06 11:26:04,421 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-07.csv
# 2024-06-06 11:26:04,426 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160608_c20240125030831.nc
# 2024-06-06 11:26:05,171 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-08.csv
# 2024-06-06 11:26:05,177 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160609_c20240125031145.nc
# 2024-06-06 11:26:05,867 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-09.csv
# 2024-06-06 11:26:05,873 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160610_c20240125031428.nc
# 2024-06-06 11:26:06,588 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-10.csv
# 2024-06-06 11:26:06,594 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160611_c20240125031646.nc
# 2024-06-06 11:26:07,312 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-11.csv
# 2024-06-06 11:26:07,318 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160612_c20240125031828.nc
# 2024-06-06 11:26:08,049 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-12.csv
# 2024-06-06 11:26:08,060 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160613_c20240125032013.nc
# 2024-06-06 11:26:08,764 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-13.csv
# 2024-06-06 11:26:08,783 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160614_c20240125032312.nc
# 2024-06-06 11:26:09,550 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-14.csv
# 2024-06-06 11:26:09,557 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160615_c20240125032530.nc
# 2024-06-06 11:26:10,296 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-15.csv
# 2024-06-06 11:26:10,302 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160616_c20240125032848.nc
# 2024-06-06 11:26:11,008 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-16.csv
# 2024-06-06 11:26:11,014 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160617_c20240125033059.nc
# 2024-06-06 11:26:11,776 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-17.csv
# 2024-06-06 11:26:11,782 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160618_c20240125033307.nc
# 2024-06-06 11:26:12,445 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-18.csv
# 2024-06-06 11:26:12,452 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160619_c20240125033523.nc
# 2024-06-06 11:26:13,218 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-19.csv
# 2024-06-06 11:26:13,225 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160620_c20240125033745.nc
# 2024-06-06 11:26:13,978 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-20.csv
# 2024-06-06 11:26:13,983 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160621_c20240125034103.nc
# 2024-06-06 11:26:14,746 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-21.csv
# 2024-06-06 11:26:14,753 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160622_c20240125034254.nc
# 2024-06-06 11:26:15,647 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-22.csv
# 2024-06-06 11:26:15,653 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160623_c20240125034643.nc
# 2024-06-06 11:26:16,384 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-23.csv
# 2024-06-06 11:26:16,390 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160624_c20240125034904.nc
# 2024-06-06 11:26:17,127 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-24.csv
# 2024-06-06 11:26:17,134 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160625_c20240125035219.nc
# 2024-06-06 11:26:17,837 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-25.csv
# 2024-06-06 11:26:17,846 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160626_c20240125035359.nc
# 2024-06-06 11:26:18,589 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-26.csv
# 2024-06-06 11:26:18,595 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160627_c20240125035645.nc
# 2024-06-06 11:26:19,331 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-27.csv
# 2024-06-06 11:26:19,348 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160628_c20240125035921.nc
# 2024-06-06 11:26:20,135 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-28.csv
# 2024-06-06 11:26:20,142 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160629_c20240125040131.nc
# 2024-06-06 11:26:20,835 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-29.csv
# 2024-06-06 11:26:20,841 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160630_c20240125040414.nc
# 2024-06-06 11:26:21,564 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-06-30.csv
# 2024-06-06 11:26:21,580 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160701_c20240125040655.nc
# 2024-06-06 11:26:22,274 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-07-01.csv
# 2024-06-06 11:26:22,289 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160702_c20240125040836.nc
# 2024-06-06 11:26:23,021 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-07-02.csv
# 2024-06-06 11:26:23,026 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160703_c20240125041010.nc
# 2024-06-06 11:26:23,773 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-07-03.csv
# 2024-06-06 11:26:23,779 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160704_c20240125041220.nc
# 2024-06-06 11:26:24,593 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-07-04.csv
# 2024-06-06 11:26:24,599 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160705_c20240125041450.nc
# 2024-06-06 11:26:25,307 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-07-05.csv
# 2024-06-06 11:26:25,314 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160706_c20240125041634.nc
# 2024-06-06 11:26:26,003 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-07-06.csv
# 2024-06-06 11:26:26,009 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160707_c20240125041806.nc
# 2024-06-06 11:26:26,747 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-07-07.csv
# 2024-06-06 11:26:26,752 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160708_c20240125042013.nc
# 2024-06-06 11:26:27,485 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-07-08.csv
# 2024-06-06 11:26:27,501 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160709_c20240125042221.nc
# 2024-06-06 11:26:28,234 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-07-09.csv
# 2024-06-06 11:26:28,247 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160710_c20240125042522.nc
# 2024-06-06 11:26:28,968 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-07-10.csv
# 2024-06-06 11:26:28,979 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160711_c20240125042807.nc
# 2024-06-06 11:26:29,747 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-07-11.csv
# 2024-06-06 11:26:29,752 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160712_c20240125043044.nc
# 2024-06-06 11:26:30,523 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-07-12.csv
# 2024-06-06 11:26:30,528 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160713_c20240125043248.nc
# 2024-06-06 11:26:31,272 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-07-13.csv
# 2024-06-06 11:26:31,279 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160714_c20240125043420.nc
# 2024-06-06 11:26:31,979 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-07-14.csv
# 2024-06-06 11:26:31,986 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160715_c20240125043624.nc
# 2024-06-06 11:26:32,717 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-07-15.csv
# 2024-06-06 11:26:32,723 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160716_c20240125043836.nc
# 2024-06-06 11:26:33,451 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-07-16.csv
# 2024-06-06 11:26:33,458 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160717_c20240125044033.nc
# 2024-06-06 11:26:34,213 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-07-17.csv
# 2024-06-06 11:26:34,220 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160718_c20240125044205.nc
# 2024-06-06 11:26:34,969 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-07-18.csv
# 2024-06-06 11:26:34,975 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160719_c20240125044441.nc
# 2024-06-06 11:26:35,710 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2016\NDVI_2016-07-19.csv
# 2024-06-06 11:26:35,716 - INFO - Processing file: data_in_nc4/NDVI\2016\VIIRS-Land_v001_NPP13C1_S-NPP_20160720_c20240125044716.nc
# ...
# 2024-06-06 11:49:25,793 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071027_c20170401073444.nc
# 2024-06-06 11:49:26,520 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-10-27.csv
# 2024-06-06 11:49:26,525 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071028_c20170401074836.nc
# 2024-06-06 11:49:27,143 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-10-28.csv
# 2024-06-06 11:49:27,161 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071029_c20170401080321.nc
# 2024-06-06 11:49:28,002 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-10-29.csv
# 2024-06-06 11:49:28,014 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071030_c20170401081816.nc
# 2024-06-06 11:49:28,628 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-10-30.csv
# 2024-06-06 11:49:28,631 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071031_c20170401083307.nc
# 2024-06-06 11:49:29,259 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-10-31.csv
# 2024-06-06 11:49:29,273 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071101_c20170401084814.nc
# 2024-06-06 11:49:29,892 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-01.csv
# 2024-06-06 11:49:29,903 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071102_c20170401090411.nc
# 2024-06-06 11:49:30,527 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-02.csv
# 2024-06-06 11:49:30,527 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071103_c20170401091922.nc
# 2024-06-06 11:49:31,143 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-03.csv
# 2024-06-06 11:49:31,158 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071104_c20170401093415.nc
# 2024-06-06 11:49:31,799 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-04.csv
# 2024-06-06 11:49:31,804 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071105_c20170401094928.nc
# 2024-06-06 11:49:32,426 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-05.csv
# 2024-06-06 11:49:32,441 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071106_c20170401100434.nc
# 2024-06-06 11:49:33,106 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-06.csv
# 2024-06-06 11:49:33,119 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071107_c20170401101929.nc
# 2024-06-06 11:49:33,844 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-07.csv
# 2024-06-06 11:49:33,848 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071108_c20170401103442.nc
# 2024-06-06 11:49:34,520 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-08.csv
# 2024-06-06 11:49:34,524 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071109_c20170401104926.nc
# 2024-06-06 11:49:35,163 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-09.csv
# 2024-06-06 11:49:35,166 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071110_c20170401110413.nc
# 2024-06-06 11:49:35,816 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-10.csv
# 2024-06-06 11:49:35,816 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071111_c20170401111856.nc
# 2024-06-06 11:49:36,492 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-11.csv
# 2024-06-06 11:49:36,492 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071112_c20170401005900.nc
# 2024-06-06 11:49:37,141 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-12.csv
# 2024-06-06 11:49:37,141 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071113_c20170401011243.nc
# 2024-06-06 11:49:37,760 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-13.csv
# 2024-06-06 11:49:37,773 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071114_c20170401012745.nc
# 2024-06-06 11:49:38,413 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-14.csv
# 2024-06-06 11:49:38,422 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071115_c20170401014254.nc
# 2024-06-06 11:49:39,057 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-15.csv
# 2024-06-06 11:49:39,061 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071116_c20170401015738.nc
# 2024-06-06 11:49:39,667 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-16.csv
# 2024-06-06 11:49:39,671 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071117_c20170401021319.nc
# 2024-06-06 11:49:40,342 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-17.csv
# 2024-06-06 11:49:40,346 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071118_c20170401022756.nc
# 2024-06-06 11:49:41,001 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-18.csv
# 2024-06-06 11:49:41,004 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071119_c20170401024240.nc
# 2024-06-06 11:49:41,631 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-19.csv
# 2024-06-06 11:49:41,634 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071120_c20170401025703.nc
# 2024-06-06 11:49:42,298 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-20.csv
# 2024-06-06 11:49:42,309 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071121_c20170401031129.nc
# 2024-06-06 11:49:42,935 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-21.csv
# 2024-06-06 11:49:42,946 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071122_c20170401032611.nc
# 2024-06-06 11:49:43,623 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-22.csv
# 2024-06-06 11:49:43,627 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071123_c20170401034056.nc
# 2024-06-06 11:49:44,265 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-23.csv
# 2024-06-06 11:49:44,269 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071124_c20170401035545.nc
# 2024-06-06 11:49:44,912 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-24.csv
# 2024-06-06 11:49:44,916 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071125_c20170401041044.nc
# 2024-06-06 11:49:45,548 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-25.csv
# 2024-06-06 11:49:45,551 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071126_c20170401042525.nc
# 2024-06-06 11:49:46,188 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-26.csv
# 2024-06-06 11:49:46,191 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071127_c20170401043948.nc
# 2024-06-06 11:49:46,827 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-27.csv
# 2024-06-06 11:49:46,830 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071128_c20170401045408.nc
# 2024-06-06 11:49:47,452 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-28.csv
# 2024-06-06 11:49:47,455 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071129_c20170401050834.nc
# 2024-06-06 11:49:48,064 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-29.csv
# 2024-06-06 11:49:48,082 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071130_c20170401052309.nc
# 2024-06-06 11:49:48,730 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-11-30.csv
# 2024-06-06 11:49:48,730 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071201_c20170401053751.nc
# 2024-06-06 11:49:49,359 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-01.csv
# 2024-06-06 11:49:49,375 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071202_c20170401055248.nc
# 2024-06-06 11:49:49,981 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-02.csv
# 2024-06-06 11:49:49,986 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071203_c20170401060739.nc
# 2024-06-06 11:49:50,578 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-03.csv
# 2024-06-06 11:49:50,578 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071204_c20170401062246.nc
# 2024-06-06 11:49:51,193 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-04.csv
# 2024-06-06 11:49:51,193 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071205_c20170401063728.nc
# 2024-06-06 11:49:51,759 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-05.csv
# 2024-06-06 11:49:51,767 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071206_c20170401065153.nc
# 2024-06-06 11:49:52,421 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-06.csv
# 2024-06-06 11:49:52,424 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071207_c20170401070613.nc
# 2024-06-06 11:49:53,001 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-07.csv
# 2024-06-06 11:49:53,014 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071208_c20170401072039.nc
# 2024-06-06 11:49:53,734 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-08.csv
# 2024-06-06 11:49:53,737 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071209_c20170401073500.nc
# 2024-06-06 11:49:54,376 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-09.csv
# 2024-06-06 11:49:54,380 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071210_c20170401074929.nc
# 2024-06-06 11:49:55,027 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-10.csv
# 2024-06-06 11:49:55,032 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071211_c20170401080357.nc
# 2024-06-06 11:49:55,636 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-11.csv
# 2024-06-06 11:49:55,651 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071212_c20170401081836.nc
# 2024-06-06 11:49:56,265 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-12.csv
# 2024-06-06 11:49:56,284 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071213_c20170401083306.nc
# 2024-06-06 11:49:56,917 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-13.csv
# 2024-06-06 11:49:56,917 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071214_c20170401084750.nc
# 2024-06-06 11:49:57,553 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-14.csv
# 2024-06-06 11:49:57,558 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071215_c20170401090219.nc
# 2024-06-06 11:49:58,381 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-15.csv
# 2024-06-06 11:49:58,384 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071216_c20170401091646.nc
# 2024-06-06 11:49:59,002 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-16.csv
# 2024-06-06 11:49:59,005 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071217_c20170401093102.nc
# 2024-06-06 11:49:59,630 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-17.csv
# 2024-06-06 11:49:59,634 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071218_c20170401094518.nc
# 2024-06-06 11:50:00,277 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-18.csv
# 2024-06-06 11:50:00,281 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071219_c20170401095943.nc
# 2024-06-06 11:50:00,913 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-19.csv
# 2024-06-06 11:50:00,917 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071220_c20170401101406.nc
# 2024-06-06 11:50:01,505 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-20.csv
# 2024-06-06 11:50:01,509 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071221_c20170401102849.nc
# 2024-06-06 11:50:02,130 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-21.csv
# 2024-06-06 11:50:02,133 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071222_c20170401104331.nc
# 2024-06-06 11:50:02,781 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-22.csv
# 2024-06-06 11:50:02,785 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071223_c20170401105806.nc
# 2024-06-06 11:50:03,435 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-23.csv
# 2024-06-06 11:50:03,440 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071224_c20170401111254.nc
# 2024-06-06 11:50:04,203 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-24.csv
# 2024-06-06 11:50:04,207 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071225_c20170401112720.nc
# 2024-06-06 11:50:04,822 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-25.csv
# 2024-06-06 11:50:04,836 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071226_c20170401114134.nc
# 2024-06-06 11:50:05,443 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-26.csv
# 2024-06-06 11:50:05,461 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071227_c20170401115549.nc
# 2024-06-06 11:50:06,134 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-27.csv
# 2024-06-06 11:50:06,137 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071228_c20170401121003.nc
# 2024-06-06 11:50:06,765 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-28.csv
# 2024-06-06 11:50:06,769 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071229_c20170401122419.nc
# 2024-06-06 11:50:07,387 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-29.csv
# 2024-06-06 11:50:07,390 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071230_c20170401123842.nc
# 2024-06-06 11:50:08,154 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-30.csv
# 2024-06-06 11:50:08,158 - INFO - Processing file: data_in_nc4/NDVI\2007\AVHRR-Land_v005_AVH13C1_NOAA-18_20071231_c20170401125450.nc
# 2024-06-06 11:50:08,794 - INFO - Processed and saved: data_in_csv/new_csv/ndvi_csv\2007\NDVI_2007-12-31.csv
# 2024-06-06 11:50:08,808 - INFO - Processing completed.

# %%
import os
import pandas as pd

# Define the path to the yearly output folder
yearly_output_folder = "raw_files/ndvi"

# Iterate over year folders in the yearly output folder
for year_folder_name in os.listdir(yearly_output_folder):
    # Construct the full path to the year folder
    year_folder_path = os.path.join(yearly_output_folder, year_folder_name)
    
    # Check if the item in the yearly output folder is indeed a directory
    if os.path.isdir(year_folder_path):
        # Collect all CSV files in the year folder
        csv_files = [file for file in os.listdir(year_folder_path) if file.endswith('.csv')]
        
        # Initialize an empty DataFrame to hold the combined data
        combined_data = pd.DataFrame(columns=['lat', 'lon'])
        
        # List to store dates extracted from file names
        dates = []
        
        # Iterate over each CSV file in the year folder
        for csv_file_name in csv_files:
            # Read the CSV file into a DataFrame
            csv_file_path = os.path.join(year_folder_path, csv_file_name)
            try:
                df = pd.read_csv(csv_file_path)
                
                # Extract the date from the CSV file name and format it as YYYYMMDD
                date = csv_file_name.split('_')[1].split('.')[0].replace('-', '')
                dates.append(date)
                
                # Rename the 'NDVI' column to the date
                df.rename(columns={'NDVI': date}, inplace=True)
                
                # Merge the current DataFrame with the combined DataFrame based on lat and lon
                combined_data = pd.merge(combined_data, df[['lat', 'lon', date]], on=['lat', 'lon'], how='outer')
            except Exception as e:
                print(f"Error processing file {csv_file_path}: {e}")
        
        # Sort dates chronologically
        dates.sort()
        
        # Reorder the columns to have lat and lon as the first two columns followed by sorted date columns
        sorted_columns = ['lat', 'lon'] + dates
        combined_data = combined_data[sorted_columns]
        
        # Save the combined DataFrame to a CSV file
        output_csv_path = os.path.join(yearly_output_folder, f"{year_folder_name}.csv")
        try:
            combined_data.to_csv(output_csv_path, index=False)
            print(f"Combined data for {year_folder_name} and saved to {output_csv_path}")
        except Exception as e:
            print(f"Error saving file {output_csv_path}: {e}")
# Out:
# Combined data for 2010 and saved to data_in_csv/new_csv/ndvi_csv\2010.csv
# Combined data for 2011 and saved to data_in_csv/new_csv/ndvi_csv\2011.csv
# Combined data for 2012 and saved to data_in_csv/new_csv/ndvi_csv\2012.csv
# Combined data for 2013 and saved to data_in_csv/new_csv/ndvi_csv\2013.csv
# Combined data for 2018 and saved to data_in_csv/new_csv/ndvi_csv\2018.csv
# Combined data for 2003 and saved to data_in_csv/new_csv/ndvi_csv\2003.csv
# Combined data for 2008 and saved to data_in_csv/new_csv/ndvi_csv\2008.csv
# Combined data for 2009 and saved to data_in_csv/new_csv/ndvi_csv\2009.csv
# Combined data for 2014 and saved to data_in_csv/new_csv/ndvi_csv\2014.csv
# Combined data for 2015 and saved to data_in_csv/new_csv/ndvi_csv\2015.csv
# Combined data for 2016 and saved to data_in_csv/new_csv/ndvi_csv\2016.csv
# Combined data for 2017 and saved to data_in_csv/new_csv/ndvi_csv\2017.csv
# Combined data for 2006 and saved to data_in_csv/new_csv/ndvi_csv\2006.csv
# Combined data for 2005 and saved to data_in_csv/new_csv/ndvi_csv\2005.csv
# Combined data for 2004 and saved to data_in_csv/new_csv/ndvi_csv\2004.csv
# Combined data for 2007 and saved to data_in_csv/new_csv/ndvi_csv\2007.csv
# Combined data for .ipynb_checkpoints and saved to data_in_csv/new_csv/ndvi_csv\.ipynb_checkpoints.csv

# %% [markdown]
# Save the yearly files seaprately to a folder (yearly_files/ndvi)

# %%
import pandas as pd
import os

def transpose_csv(input_folder, output_folder):
    # Walk through the directory tree
    for root, dirs, files in os.walk(input_folder):
        for filename in files:
            # Skip hidden macOS metadata files
            if filename.endswith('.csv') and not filename.startswith('._'):
                input_file = os.path.join(root, filename)
                try:
                    # Read the CSV file into a pandas DataFrame
                    df = pd.read_csv(input_file)
                    
                    # Transpose the DataFrame
                    df_transposed = df.T
                    
                    # Construct the output folder path mirroring the input folder structure
                    relative_path = os.path.relpath(root, input_folder)
                    output_subfolder = os.path.join(output_folder, relative_path)
                    
                    # Create the output subfolder if it doesn't exist
                    os.makedirs(output_subfolder, exist_ok=True)
                    
                    # Generate the output filename
                    output_file = os.path.join(output_subfolder, filename)
                    
                    # Write the transposed DataFrame to a new CSV file
                    df_transposed.to_csv(output_file, index=True, header=False)
                    print(f"Transposed and saved: {input_file} -> {output_file}")
                except Exception as e:
                    print(f"Error processing file {input_file}: {e}")

if __name__ == "__main__":
    input_folder = "yearly_files/ndvi"
    output_folder = "transposed/ndvi"

    os.makedirs(output_folder, exist_ok=True)

    transpose_csv(input_folder, output_folder)
    print("Transposition complete.")

# %%
import csv
import os
import pandas as pd

def transform_files(input_folder, output_file):
    # Initialize an empty DataFrame to store transformed data from all files
    combined_df = pd.DataFrame()

    # Iterate through each file in the input folder
    for filename in os.listdir(input_folder):
        # Skip hidden metadata files
        if filename.endswith('.csv') and not filename.startswith('._'):
            input_file = os.path.join(input_folder, filename)
            try:
                # Read the file and transform the data
                transformed_df = transform_file(input_file)
                # Append transformed data to the combined DataFrame
                combined_df = pd.concat([combined_df, transformed_df], ignore_index=True)
            except Exception as e:
                print(f"Error processing file {input_file}: {e}")

    # Write the combined DataFrame to a single output file
    combined_df.to_csv(output_file, index=False)
    print("Transformation complete. Combined data saved to:", output_file)

def transform_file(input_file):
    transformed_rows = []

    with open(input_file, 'r') as f_in:
        reader = csv.reader(f_in)
        latitudes = next(reader)
        longitudes = next(reader)
        # Skip the header row
        next(reader)
        for row in reader:
            date = row[0]
            values = row[1:]
            for lat, lon, value in zip(latitudes, longitudes, values):
                transformed_rows.append([lat, lon, date, value])

    # Convert transformed rows to a DataFrame
    transformed_df = pd.DataFrame(transformed_rows, columns=['Lat', 'Lon', 'Date', 'NDVI'])  # Adjust column names as needed
    return transformed_df

if __name__ == "__main__":
    input_folder = 'transposed/ndvi'  # Specify the input folder containing CSV files
    output_file = 'variables/ndvi.csv'  # Specify the output file name
    
    transform_files(input_folder, output_file)
